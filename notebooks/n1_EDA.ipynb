# %% [markdown]
# ## EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %store -r df1

# %%
df1.describe()
# Out:
#        distance_seattle  property_age  rooms_per_floor      sqft_lot  \
# count      15742.000000  15742.000000     15742.000000  15742.000000
# mean          10.363642     46.145090         3.985293   7254.739169
# std            5.518193     29.510392         1.427181   3752.395860
# min            0.330000     -1.000000         0.750000    520.000000
# 25%            5.610000     21.000000         3.000000   4750.000000
# 50%            9.805000     46.000000         3.750000   7168.500000
# 75%           14.380000     66.000000         4.750000   9219.750000
# max           22.250000    115.000000        11.500000  21370.000000
#
#         sqft_living          price  renovation_1  renovation_unknown  \
# count  15742.000000   15742.000000  15742.000000        15742.000000
# mean    1840.128827  450911.570576      0.027315            0.179456
# std      672.382422  171196.157571      0.163006            0.383746
# ...

# %% [markdown]
# Let's explore the relationship between our target variable 'price' and the features we suspect have an influence on it.

# %% [markdown]
# ### Question 1: Location

# %%
sns.jointplot('distance_seattle', 'price', data=df1, kind='reg')
plt.show()

# %% [markdown]
# ### Question 2: Property Age

# %%
sns.jointplot('property_age', 'price', data=df1, kind='reg')
plt.show()

# %% [markdown]
# ### Question 3: Size and Distribution

# %%
sns.jointplot('sqft_living', 'price', data=df1, kind='reg')
plt.show()

# %%
sns.jointplot('rooms_per_floor', 'price', data=df1, kind='reg')
plt.show()

# %% [markdown]
# ### Question 4: Waterfront & Renovation

# %%
sns.jointplot('waterfront_1', 'price', data=df1, kind='reg')
plt.show()

# %%
sns.jointplot('renovation_1', 'price', data=df1, kind='reg')
plt.show()
