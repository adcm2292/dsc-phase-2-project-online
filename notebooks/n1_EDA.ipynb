# %% [markdown]
# ## EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %store -r df1

# %%
df1.describe()
# Out:
#        distance_seattle  property_age  rooms_per_floor   sqft_living  \
# count      14328.000000  14328.000000     14328.000000  14328.000000
# mean          10.637792     47.677136         3.708012   1685.060441
# std            5.885533     29.764941         1.133331    527.717693
# min            0.330000     -1.000000         0.750000    370.000000
# 25%            5.490000     23.000000         2.750000   1280.000000
# 50%            9.850000     47.000000         3.380000   1650.000000
# 75%           15.220000     67.000000         4.750000   2080.000000
# max           22.810000    115.000000         6.000000   2830.000000
#
#                price  renovation_1  renovation_unknown  waterfront_1  \
# count   14328.000000  14328.000000        14328.000000  14328.000000
# mean   430268.904453      0.028197            0.179299      0.002443
# std    163521.948393      0.165540            0.383616      0.049366
# min     78000.000000      0.000000            0.000000      0.000000
# 25%    300000.000000      0.000000            0.000000      0.000000
# 50%    409900.000000      0.000000            0.000000      0.000000
# 75%    540625.000000      0.000000            0.000000      0.000000
# max    873000.000000      1.000000            1.000000      1.000000
#
#        waterfront_unknown
# count        14328.000000
# mean             0.110483
# std              0.313502
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              0.000000
# max              1.000000

# %% [markdown]
# ### Question 1: Location

# %%
sns.jointplot('distance_seattle', 'price', data=df1, kind='reg')
plt.show()

# %% [markdown]
# ### Question 2: Property Age

# %%
sns.jointplot('property_age', 'price', data=df1, kind='reg')
plt.show()

# %% [markdown]
# ### Question 3: Size and Distribution

# %%
sns.jointplot('sqft_living', 'price', data=df1, kind='reg')
plt.show()

# %%
sns.jointplot('rooms_per_floor', 'price', data=df1, kind='reg')
plt.show()

# %% [markdown]
# ### Question 4: Waterfront & Renovation

# %%
sns.jointplot('waterfront_1', 'price', data=df1, kind='reg')
plt.show()

# %%
sns.jointplot('renovation_1', 'price', data=df1, kind='reg')
plt.show()
